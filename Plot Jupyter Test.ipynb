# %%
import flirimageextractor
from matplotlib import cm

# %%
flir = flirimageextractor.FlirImageExtractor()
flir.process_image('/Users/aidankinzett/Documents/Git/FlirImageExtractor/examples/ax8.jpg', RGB=True)
flir.plot(palette=cm.hot)
