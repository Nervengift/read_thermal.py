# %%
import flirimageextractor
from matplotlib import cm

# %matplotlib inline

# %%
flir = flirimageextractor.FlirImageExtractor()
flir.process_image('/Users/aidankinzett/Desktop/DJI_0025.JPG')
flir.plot(palette=cm.hot)
